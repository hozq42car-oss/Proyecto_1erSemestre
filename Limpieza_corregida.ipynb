# %%
import pandas as pd

# %%
df=pd.read_csv('df_sucio2.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park      NaN
# 1  2595                             Skylit Midtown Castle   2845.0
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !   4632.0
# 3  3831                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0          NaN            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902   -73.9419
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem    Auto%#  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (49002, 16)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df['id'].unique()
# Out:
# array(['2539', '2595', '3647', ..., '21675209', '22191760', '12740226'],
#       shape=(46501,), dtype=object)

# %%
df2=df

# %%
df2=df2.dropna(subset=['id'])
df2.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park      NaN
# 1  2595                             Skylit Midtown Castle   2845.0
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !   4632.0
# 3  3831                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0          NaN            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902   -73.9419
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem    Auto%#  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
dic={'Auto%#': '0'}
df2['id']=df2['id'].replace(dic)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\2371185560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['id']=df2['id'].replace(dic)

# %%
df2['id']=df2['id'].astype(int)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\4080668048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['id']=df2['id'].astype(int)

# %%
df2.isnull().sum()
# Out:
# id                                    0
# name                               1443
# host_id                            1438
# host_name                          1428
# neighbourhood_group                1418
# neighbourhood                      1417
# latitude                           1429
# longitude                          1425
# room_type                          1427
# price                              1428
# minimum_nights                     1422
# number_of_reviews                  1424
# last_review                       10856
# reviews_per_month                 10892
# calculated_host_listings_count     1425
# availability_365                   1433
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            46089 non-null  object
#  2   host_id                         46094 non-null  float64
#  3   host_name                       46104 non-null  object
#  4   neighbourhood_group             46114 non-null  object
#  5   neighbourhood                   46115 non-null  object
#  6   latitude                        46103 non-null  object
#  7   longitude                       46107 non-null  object
#  8   room_type                       46105 non-null  object
#  9   price                           46104 non-null  float64
#  10  minimum_nights                  46110 non-null  float64
#  11  number_of_reviews               46108 non-null  float64
# ...

# %%
df['name'].unique()
# Out:
# array(['Clean & quiet apt home by the park', 'Skylit Midtown Castle',
#        'THE VILLAGE OF HARLEM....NEW YORK !', ...,
#        'Private room in a 2 Bedroom apartment - Chelsea',
#        'Bright, spacious and quiet two-bedroom Chelsea apt',
#        'Comfortable Couch in a Great Location! Bushwick.'],
#       shape=(46495,), dtype=object)

# %%
df2['name']=df2['name'].fillna("Sin nombre")
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\3513800373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['name']=df2['name'].fillna("Sin nombre")

# %%
df2['name']=df2['name'].astype(object)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\220674303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['name']=df2['name'].astype(object)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         46094 non-null  float64
#  3   host_name                       46104 non-null  object
#  4   neighbourhood_group             46114 non-null  object
#  5   neighbourhood                   46115 non-null  object
#  6   latitude                        46103 non-null  object
#  7   longitude                       46107 non-null  object
#  8   room_type                       46105 non-null  object
#  9   price                           46104 non-null  float64
#  10  minimum_nights                  46110 non-null  float64
#  11  number_of_reviews               46108 non-null  float64
# ...

# %%
df2['name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['host_id'].unique()
# Out:
# array([           nan, 2.84500000e+03, 4.63200000e+03, ...,
#        2.34929520e+07, 2.85048390e+07, 1.76964342e+08], shape=(36480,))

# %%
df['host_id'].isnull().sum()
# Out:
# np.int64(1470)

# %%
df2["host_id"]=df["host_id"].fillna("0")
df2.head()
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\3624518895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["host_id"]=df["host_id"].fillna("0")
#      id                                              name host_id  \
# 0  2539                Clean & quiet apt home by the park       0
# 1  2595                             Skylit Midtown Castle  2845.0
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !  4632.0
# 3  3831                   Cozy Entire Floor of Brownstone  4869.0
# 4  5022  Entire Apt: Spacious Studio/Loft by central park  7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0          NaN            Brooklyn    Kensington  40.64749  -73.97237
# ...

# %%
df2['host_id']=df2['host_id'].astype(int)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\1919776223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['host_id']=df2['host_id'].astype(int)

# %%
df2['host_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['host_name'].unique()
# Out:
# array([nan, 'Jennifer', 'Elisabeth', ..., 'Abayomi', 'Alberth',
#        'Ilgar & Aysel'], shape=(11242,), dtype=object)

# %%
df3=df2

# %%
df3["host_name"]=df2["host_name"].fillna("Anónimo")
df3
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\2774221241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["host_name"]=df2["host_name"].fillna("Anónimo")
#              id                                              name   host_id  \
# 0          2539                Clean & quiet apt home by the park         0
# 1          2595                             Skylit Midtown Castle      2845
# 2          3647               THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                   Cozy Entire Floor of Brownstone      4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                               ...       ...
# ...

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', nan, 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df3['neighbourhood_group'] = df2['neighbourhood_group'].fillna('Sin dato')
df3.head()
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\3041217828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['neighbourhood_group'] = df2['neighbourhood_group'].fillna('Sin dato')
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park        0
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# ...

# %%
df3['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Sin dato', 'Queens', 'Staten Island',
#        'Bronx'], dtype=object)

# %%
df['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', nan, 'Crown Heights', 'Park Slope',
#        'Windsor Terrace', 'Inwood', 'East Village', 'Greenpoint',
#        'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Chelsea', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Roosevelt Island', 'Greenwich Village',
# ...

# %%
df3['neighbourhood'] = df2['neighbourhood'].fillna('Valor Desconocido')
df3.head()
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\886150538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['neighbourhood'] = df2['neighbourhood'].fillna('Valor Desconocido')
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park        0
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# ...

# %%
df3['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Valor Desconocido',
#        'Crown Heights', 'Park Slope', 'Windsor Terrace', 'Inwood',
#        'East Village', 'Greenpoint', 'Bushwick', 'Flatbush',
#        'Lower East Side', 'Prospect-Lefferts Gardens', 'Long Island City',
#        'Kips Bay', 'SoHo', 'Chelsea', 'Upper East Side',
#        'Prospect Heights', 'Washington Heights', 'Woodside',
#        'Brooklyn Heights', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'Carroll Gardens',
#        'St. George', 'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Roosevelt Island', 'Greenwich Village',
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        46103 non-null  object
#  7   longitude                       46107 non-null  object
#  8   room_type                       46105 non-null  object
#  9   price                           46104 non-null  float64
#  10  minimum_nights                  46110 non-null  float64
#  11  number_of_reviews               46108 non-null  float64
# ...

# %%
df['latitude'].unique()
# Out:
# array(['40.64749', '40.75362', '40.80902', ..., '40.70184', '40.81475',
#        '40.8785'], shape=(18716,), dtype=object)

# %%
df3['latitude'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 47532 entries, 0 to 49001
# Series name: latitude
# Non-Null Count  Dtype
# --------------  -----
# 46103 non-null  object
# dtypes: object(1)
# memory usage: 742.7+ KB

# %%
df3['latitude']=df3['latitude'].fillna('0')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\2216467373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['latitude']=df3['latitude'].fillna('0')

# %%
df3['latitude']=df3['latitude'].replace(dic)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\1152546252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['latitude']=df3['latitude'].replace(dic)

# %%
df3.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                          1425
# room_type                          1427
# price                              1428
# minimum_nights                     1422
# number_of_reviews                  1424
# last_review                       10856
# reviews_per_month                 10892
# calculated_host_listings_count     1425
# availability_365                   1433
# dtype: int64

# %%
df3['latitude']=df3['latitude'].astype(float)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\3044378885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['latitude']=df3['latitude'].astype(float)

# %%
df['longitude'].unique()
# Out:
# array(['-73.97237', '-73.98377', '-73.9419', ..., '-73.93614',
#        '-73.80844', '-73.83474'], shape=(14449,), dtype=object)

# %%
df4=df3

# %%
df4['longitude']=df4['longitude'].fillna('0')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\105675783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['longitude']=df4['longitude'].fillna('0')

# %%
df4['longitude']=df4['longitude'].replace(dic)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\927286145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['longitude']=df4['longitude'].replace(dic)

# %%
df4['longitude']=df4['longitude'].astype(float)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\2918794015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['longitude']=df4['longitude'].astype(float)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        47532 non-null  float64
#  7   longitude                       47532 non-null  float64
#  8   room_type                       46105 non-null  object
#  9   price                           46104 non-null  float64
#  10  minimum_nights                  46110 non-null  float64
#  11  number_of_reviews               46108 non-null  float64
# ...

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Auto%#', 'Shared room', nan],
#       dtype=object)

# %%
df4['room_type']=df4['room_type'].fillna('Cuarto Sencillo')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\3486218046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['room_type']=df4['room_type'].fillna('Cuarto Sencillo')

# %%
dic2={'Auto%#' : 'Sin dato'}

# %%
dic4={'Auto%#': 'Cuarto Sencillo'}

# %%
df4['room_type']=df4['room_type'].replace(dic4)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\2225540310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['room_type']=df4['room_type'].replace(dic4)

# %%
df4['room_type']=df4['room_type'].astype(object)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\453247016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['room_type']=df4['room_type'].astype(object)

# %%
df4.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              1428
# minimum_nights                     1422
# number_of_reviews                  1424
# last_review                       10856
# reviews_per_month                 10892
# calculated_host_listings_count     1425
# availability_365                   1433
# dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        47532 non-null  float64
#  7   longitude                       47532 non-null  float64
#  8   room_type                       47532 non-null  object
#  9   price                           46104 non-null  float64
#  10  minimum_nights                  46110 non-null  float64
#  11  number_of_reviews               46108 non-null  float64
# ...

# %%
df['price'].unique()
# Out:
# array([  149.,   225.,   150.,    89.,    80.,   200.,    60.,    79.,
#          135.,    85.,    nan,   120.,   140.,   215.,    99.,   190.,
#          299.,   130.,   110.,    44.,   180.,    50.,    52.,    55.,
#           70.,    35.,    40.,    68.,   115.,   151.,   228.,   144.,
#           69.,    49.,   375.,   250.,   275.,   230.,    51.,    65.,
#          105.,    95.,   145.,   285.,    94.,   800.,   131.,    98.,
#          100.,   125.,   175.,   500.,   101.,   220.,    59.,   350.,
#          199.,   325.,   235.,   170.,   400.,    75.,    90.,   185.,
#           77.,    76.,   160.,   195.,   156.,   219.,   475.,   165.,
#          196.,    83.,   123.,   265.,   249.,   121.,    45.,    71.,
#           64.,   159.,   189.,   239.,   305.,   155.,    92.,    36.,
#           37.,   205.,    39.,   390.,   129.,   212.,   124.,   122.,
#          109.,   575.,   229.,   169.,   113.,   179.,   349.,   139.,
# ...

# %%
df5=df4

# %%
df5['price']=df4['price'].fillna('0')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\590171891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['price']=df4['price'].fillna('0')

# %%
df5['price']=df5['price'].astype(int)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\1797494408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['price']=df5['price'].astype(int)

# %%
df5.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                     1422
# number_of_reviews                  1424
# last_review                       10856
# reviews_per_month                 10892
# calculated_host_listings_count     1425
# availability_365                   1433
# dtype: int64

# %%
df['minimum_nights'].unique()
# Out:
# array([1.00e+00, 3.00e+00, 1.00e+01, 4.50e+01, 2.00e+00, 5.00e+00,
#        4.00e+00, 9.00e+01, 7.00e+00, 1.40e+01, 6.00e+01, 2.90e+01,
#        3.00e+01, 1.80e+02, 9.00e+00,      nan, 3.10e+01, 6.00e+00,
#        1.50e+01, 8.00e+00, 2.60e+01, 2.80e+01, 2.00e+02, 5.00e+01,
#        1.70e+01, 2.10e+01, 1.10e+01, 2.50e+01, 1.30e+01, 3.50e+01,
#        1.80e+01, 2.00e+01, 4.00e+01, 4.40e+01, 6.50e+01, 5.50e+01,
#        1.20e+02, 3.65e+02, 1.22e+02, 2.70e+01, 1.90e+01, 2.40e+02,
#        8.80e+01, 1.15e+02, 1.50e+02, 3.70e+02, 1.60e+01, 8.00e+01,
#        1.81e+02, 2.65e+02, 3.00e+02, 5.90e+01, 1.85e+02, 3.60e+02,
#        5.60e+01, 1.20e+01, 7.00e+01, 3.90e+01, 2.40e+01, 3.20e+01,
#        1.00e+03, 1.10e+02, 2.70e+02, 2.20e+01, 7.50e+01, 2.50e+02,
#        6.20e+01, 2.30e+01, 1.25e+03, 3.64e+02, 7.40e+01, 1.98e+02,
#        1.00e+02, 5.00e+02, 4.30e+01, 9.10e+01, 4.80e+02, 5.30e+01,
#        9.90e+01, 1.60e+02, 4.70e+01, 1.86e+02, 3.66e+02, 6.80e+01,
# ...

# %%
df5['minimum_nights']=df5['minimum_nights'].fillna('0')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\955165787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['minimum_nights']=df5['minimum_nights'].fillna('0')

# %%
df5['minimum_nights']=df5['minimum_nights'].astype(int)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\14523137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['minimum_nights']=df5['minimum_nights'].astype(int)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        47532 non-null  float64
#  7   longitude                       47532 non-null  float64
#  8   room_type                       47532 non-null  object
#  9   price                           47532 non-null  int64
#  10  minimum_nights                  47532 non-null  int64
#  11  number_of_reviews               46108 non-null  float64
# ...

# %%
df['number_of_reviews'].unique()
# Out:
# array([  9.,  45.,   0., 270.,  74.,  49., 430., 118., 160.,  53., 188.,
#        167., 113.,  27., 148., 198., 260., 130.,  39.,  71.,  88.,  19.,
#         58., 108.,  29., 242., 197., 273., 168., 231., 214., 245.,  15.,
#         25.,  81.,  97.,  11., 248.,  61., 135., 112.,  73.,  82., 328.,
#         nan, 105., 289., 138.,  21.,  42.,   5.,  66., 143., 191., 338.,
#        106., 190.,  23., 142.,  54.,  70.,  16.,  94., 194.,   2., 174.,
#         24., 166.,   1.,  30., 139., 233.,  68.,  46., 335., 162., 170.,
#        334.,  12., 467.,   7.,  38., 324., 115., 354., 195.,  13.,  36.,
#         63., 155., 193.,  32.,  50.,  26., 426., 227.,  84.,   3.,  10.,
#          4., 124., 200.,  79.,  34., 134., 126., 234., 202.,  28.,  14.,
#         80., 294., 150.,  47., 219., 114., 213.,  86.,  18., 206., 122.,
#         33.,  52.,  51., 199.,  41., 109., 151., 285.,   6., 358., 226.,
#        104., 204., 253., 129.,  37.,  69.,  17., 222., 205., 458., 183.,
# ...

# %%
df5['number_of_reviews']=df5['number_of_reviews'].fillna('0.1')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\2787745573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['number_of_reviews']=df5['number_of_reviews'].fillna('0.1')

# %%
df5['number_of_reviews']=df2['number_of_reviews'].astype(float)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\754378241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['number_of_reviews']=df2['number_of_reviews'].astype(float)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        47532 non-null  float64
#  7   longitude                       47532 non-null  float64
#  8   room_type                       47532 non-null  object
#  9   price                           47532 non-null  int64
#  10  minimum_nights                  47532 non-null  int64
#  11  number_of_reviews               47532 non-null  float64
# ...

# %%
df6=df5

# %%
df['last_review'].unique()
# Out:
# array(['2018-10-19', '2019-05-21', nan, ..., '2017-12-23', '2018-01-29',
#        '2018-03-29'], shape=(1750,), dtype=object)

# %%
df6['last_review']=df6['last_review'].fillna('0')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\2098004600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['last_review']=df6['last_review'].fillna('0')

# %%
df6['last_review']=df5['last_review'].astype(object)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\935294564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['last_review']=df5['last_review'].astype(object)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        47532 non-null  float64
#  7   longitude                       47532 non-null  float64
#  8   room_type                       47532 non-null  object
#  9   price                           47532 non-null  int64
#  10  minimum_nights                  47532 non-null  int64
#  11  number_of_reviews               47532 non-null  float64
# ...

# %%
df['reviews_per_month'].unique()
# Out:
# array(['0.21', '0.38', nan, '4.64', '0.1', '0.59', '0.4', '3.47', '0.99',
#        '1.33', '0.43', 'Auto%#', '1.34', '0.91', '0.22', '1.72', '2.12',
#        '4.44', '0.07', '1.09', '0.37', '0.61', '0.73', '1.37', '0.49',
#        '1.11', '0.24', '2.04', '1.42', '1.65', '0.66', '1.96', '1.81',
#        '2.08', '0.39', '0.23', '0.69', '0.84', '2.25', '0.52', '1.16',
#        '1.01', '0.63', '0.7', '2.82', '0.17', '2.49', '1.19', '0.3',
#        '0.12', '0.57', '0.16', '4.72', '1.4', '1.26', '1.64', '1.6',
#        '0.92', '0.2', '1.5', '1.28', '0.54', '0.62', '0.15', '0.53',
#        '1.73', '0.05', '1.54', '0.28', '3.4', '1.57', '1.05', '0.71',
#        '0.11', '0.27', '1.23', '0.87', '2.09', '0.6', '0.55', '3.02',
#        '0.79', '1.46', '1.61', '3.0', '0.13', '4.22', '0.06', '3.01',
#        '3.2', '2.03', '0.08', '0.19', '0.33', '0.58', '1.86', '0.29',
#        '0.45', '0.25', '0.02', '3.89', '0.77', '0.03', '0.04', '2.19',
# ...

# %%
df6['reviews_per_month']=df6['reviews_per_month'].fillna('0.0')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\3786678367.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['reviews_per_month']=df6['reviews_per_month'].fillna('0.0')

# %%
df6['reviews_per_month']=df6['reviews_per_month'].replace(dic)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\3415232775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['reviews_per_month']=df6['reviews_per_month'].replace(dic)

# %%
df6['reviews_per_month']=df6['reviews_per_month'].astype(float)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\948469349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['reviews_per_month']=df6['reviews_per_month'].astype(float)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        47532 non-null  float64
#  7   longitude                       47532 non-null  float64
#  8   room_type                       47532 non-null  object
#  9   price                           47532 non-null  int64
#  10  minimum_nights                  47532 non-null  int64
#  11  number_of_reviews               47532 non-null  float64
# ...

# %%
df['calculated_host_listings_count'].unique()
# Out:
# array(['6', '2', '1', '4', '3', nan, 'Auto%#', '5', '7', '13', '28', '11',
#        '8', '9', '52', '18', '15', '19', '10', '39', '29', '12', '96',
#        '21', '14', '26', '34', '43', '121', '37', '49', '31', '91', '16',
#        '87', '33', '23', '50', '20', '25', '232', '17', '47', '103', '65',
#        '30', '27', '327', '32'], dtype=object)

# %%
df6['calculated_host_listings_count']=df6['calculated_host_listings_count'].fillna('0')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\1720880091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['calculated_host_listings_count']=df6['calculated_host_listings_count'].fillna('0')

# %%
df6['calculated_host_listings_count']=df6['calculated_host_listings_count'].replace(dic)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\3259855465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['calculated_host_listings_count']=df6['calculated_host_listings_count'].replace(dic)

# %%
df6['calculated_host_listings_count']=df6['calculated_host_listings_count'].astype(int)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\954185610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['calculated_host_listings_count']=df6['calculated_host_listings_count'].astype(int)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        47532 non-null  float64
#  7   longitude                       47532 non-null  float64
#  8   room_type                       47532 non-null  object
#  9   price                           47532 non-null  int64
#  10  minimum_nights                  47532 non-null  int64
#  11  number_of_reviews               47532 non-null  float64
# ...

# %%
df['availability_365'].unique()
# Out:
# array(['365', '355', '194', '0', '129', '220', '188', '6', '39', '314',
#        '333', '46', '321', '12', '21', '249', '347', '364', '304', '233',
#        '85', '75', '311', '67', '255', '284', '359', '269', '340', '22',
#        '96', '345', '273', '309', '95', '215', '265', '192', '251', '302',
#        '140', '234', '257', '30', '301', '294', '320', '154', '263',
#        '180', '231', '297', '292', nan, '72', '362', '336', '116', '88',
#        'Auto%#', '224', '322', '324', '132', '295', '238', '209', '328',
#        '38', '7', '272', '26', '288', '317', '207', '185', '158', '9',
#        '198', '219', '342', '312', '243', '152', '137', '222', '346',
#        '208', '279', '250', '164', '298', '260', '107', '199', '299',
#        '20', '318', '245', '189', '307', '310', '213', '278', '16', '178',
#        '275', '163', '34', '280', '1', '170', '214', '248', '262', '339',
#        '10', '290', '230', '53', '126', '3', '177', '246', '225', '18',
# ...

# %%
df6['availability_365']=df6['availability_365'].fillna('0.1')
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\1791335572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['availability_365']=df6['availability_365'].fillna('0.1')

# %%
dic3={'Auto%#': '0.1'}
df6['availability_365']=df6['availability_365'].replace(dic3)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\912076280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['availability_365']=df6['availability_365'].replace(dic3)

# %%
df6['availability_365']=df6['availability_365'].astype(float)
# Out:
# C:\Users\orcar\AppData\Local\Temp\ipykernel_15108\1570297733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['availability_365']=df6['availability_365'].astype(float)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47532 entries, 0 to 49001
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              47532 non-null  int64
#  1   name                            47532 non-null  object
#  2   host_id                         47532 non-null  int64
#  3   host_name                       47532 non-null  object
#  4   neighbourhood_group             47532 non-null  object
#  5   neighbourhood                   47532 non-null  object
#  6   latitude                        47532 non-null  float64
#  7   longitude                       47532 non-null  float64
#  8   room_type                       47532 non-null  object
#  9   price                           47532 non-null  int64
#  10  minimum_nights                  47532 non-null  int64
#  11  number_of_reviews               47532 non-null  float64
# ...

# %%
df6.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df7=df6

# %%
df7 = df7.rename(columns={
    'name': 'nombre_del_alojamiento',
    'host_id': 'id_del_anfitrion',
    'host_name': 'nombre_del_anfitrion',
    'neighbourhood_group': 'nombre_de_la_ciudad',
    'neighbourhood': 'vecindario',
    'latitude': 'latitud',
    'longitude': 'longitud',
    'room_type': 'tipo_de_cuarto',
    'price': 'precio',
    'minimum_nights': 'mínimo_de_noches',
    'number_of_reviews': 'numero_de_reseñas',
    'last_review': 'última_reseña',
    'reviews_per_month': 'reseñas_por_mes',
    'calculated_host_listings_count': 'cantidad_de_alojamientos',
    'availability_365': 'disponibilidad_al_año'
})
df7.head(1)
# Out:
#      id              nombre_del_alojamiento  id_del_anfitrion  \
# 0  2539  Clean & quiet apt home by the park                 0
#
#   nombre_del_anfitrion nombre_de_la_ciudad  vecindario   latitud  longitud  \
# 0              Anónimo            Brooklyn  Kensington  40.64749 -73.97237
#
#   tipo_de_cuarto  precio  mínimo_de_noches  numero_de_reseñas última_reseña  \
# 0   Private room     149                 1                9.0    2018-10-19
#
#    reseñas_por_mes  cantidad_de_alojamientos  disponibilidad_al_año
# 0             0.21                         6                  365.0

# %%
df7.to_csv("df_limpio.csv", index=True)
